# %% [markdown]
# <a href="https://colab.research.google.com/github/itz-aniket-akm/LABS/blob/main/Lab_1_ML_ANIKET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Student Name: Aniket Mishra

# %% [markdown]
# #Quetion 0
# Write down 3-5 methods applicable to each data type. (Hint: extend, reverse, etc.)
#
# ANS:- For *list its {append, insert, remove, sort}
# *String {upper, lover, replace, split}
# *Dictionaries {get, keys, values, items}
# *Tuples {index, count, len}

# %% [markdown]
# Question 1 :
# Define a function, which takes in two strings A and B. Reverses the first string A, adds it to B, and returns the final string.

# %%
def reverse_and_concatenate(A, B):
    reversed_A = A[::-1]
    result = reversed_A + B
    return result
string_A = "Hello"
string_B = " Python!"
final_string = reverse_and_concatenate(string_A, string_B)
print(final_string)
# Out:
# olleH Python!

# %% [markdown]
# Question 2 :
# Given a list having Names, work_hours, and gender, Write a function to print name of the female worker that worked the most hours. Also how much do should she be paid if the pay is $ 20 per hour.
# work_hours = [('Abby',100 , 'F'),('Billy',400, 'M'),('Cassie',800,'F'), ('Maggi',600,'F'),('Alex',500,'M'),('Raj',225,'M'),('Penny',920,'F'),('Ben',300,'M')]
# Answer : the female worker that worked the most hours is Penny and she should be paid 18400

# %%
def find_highest_paid_female_worker(work_hours, pay_rate=20):
    hours_worked = 0
    female_worker = None

    for name, hours, gender in work_hours:
        if gender == 'F' and hours > hours_worked:
            hours_worked = hours
            female_worker = name
    if female_worker:
        payment = hours_worked * pay_rate
        return female_worker, payment
    else:
        return "No female workers found", 0
work_hours = [('Abby', 100, 'F'), ('Billy', 400, 'M'), ('Cassie', 800, 'F'), ('Maggi', 600, 'F'),('Alex', 500, 'M'), ('Raj', 225, 'M'), ('Penny', 920, 'F'), ('Ben', 300, 'M')]

name,payment =  find_highest_paid_female_worker(work_hours)
if name != "No female workers found":
    print(f"The female worker who worked the most hours is {name}.")
    print(f"She should be paid ${payment}.")
else:
    print(name)
# Out:
# The female worker who worked the most hours is Penny.
# She should be paid $18400.

# %% [markdown]
# Question 3 :
# a)Create a 5x5 matrix of the following form,
# [[1,1]
# [2,2]]
# i.e. each row is increasing and has repetive elements.
# Hint : you can use hstack, vstack etc.
# b) find dot product of the matrix with any matrix. (Figure out the size/ shape of the matrix)

# %%
import numpy as np

# Create a 2x2 matrix with the desired pattern
pattern_matrix = np.array([[1, 1], [2, 2]])

#
matrix_5x5 = np.tile(pattern_matrix, (5 // 2,5//2))


print(matrix_5x5)




mat1 = np.array([[1, 2], [3, 4]])
mat2 = np.array([[5, 6], [7, 8]])

if mat1.shape[1] == mat2.shape[0]:
    dot_product = np.dot(mat1, mat2)

    print("Dot Product Result:")
    print(dot_product)
else:
    print("Matrix dimensions are not compatible for dot product.")
# Out:
# [[1 1 1 1]
#  [2 2 2 2]
#  [1 1 1 1]
#  [2 2 2 2]]
# Dot Product Result:
# [[19 22]
#  [43 50]]

# %% [markdown]
# QUESTION :Upload an image to your google drive, Use plt.imread to read image from the google drive and then print that image using plt.imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Specify the path to your image file
image_path = '/content/drive/MyDrive/virat iiit.jpeg'

# Read the image using plt.imread
img = mpimg.imread('/content/drive/MyDrive/virat iiit.jpeg')

# Display the image using plt.imshow
plt.imshow(img)
plt.axis('off')  # Turn off axis labels and ticks
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
